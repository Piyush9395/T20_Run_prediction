# %% [markdown]
# #Import necessary libraries

# %%
import numpy as np

import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %% [markdown]
# # Collect the full paths of all files in the specified directory into a list

# %%
filenames = []
for file in os.listdir('/content/drive/MyDrive/Project/T20_run_prediction/t20s'):
  filenames.append(os.path.join('/content/drive/MyDrive/Project/T20_run_prediction/t20s',file))
#

# %% [markdown]
# # Get the first five file paths from the filenames list

# %%
filenames[0:5]
# Out:
# ['/content/drive/MyDrive/Project/T20_run_prediction/t20s/1185188.yaml',
#  '/content/drive/MyDrive/Project/T20_run_prediction/t20s/1185186.yaml',
#  '/content/drive/MyDrive/Project/T20_run_prediction/t20s/1184262.yaml',
#  '/content/drive/MyDrive/Project/T20_run_prediction/t20s/1185181.yaml',
#  '/content/drive/MyDrive/Project/T20_run_prediction/t20s/1185316.yaml']

# %% [markdown]
# #Read and normalize JSON data from each file in 'filenames' into a DataFrame, handling different JSON structures (single dictionary or list of dictionaries),
# # and appending them to 'final_df'; includes error handling for unsupported formats or unexpected exceptions

# %%
final_df = pd.DataFrame()
count = 0
for file in tqdm(filenames):
    with open(file, 'r') as f:
        try:
            data = safe_load(f)
            df = pd.json_normalize(data)  # Try normalizing directly
        except NotImplementedError:
            try:
                # Handle case where data is a list of dictionaries
                df = pd.DataFrame()
                for item in data:
                    temp_df = pd.json_normalize(item)
                    df = pd.concat([df, temp_df], ignore_index=True)
            except Exception as e:
                print(f"Error processing file {file}: {e}")
                continue  # Skip to the next file

        df['match_id'] = count
        final_df = pd.concat([final_df, df], ignore_index=True)
        count += 1
# Out:
#  69%|██████▊   | 990/1443 [06:02<02:47,  2.70it/s]
# Error processing file /content/drive/MyDrive/Project/T20_run_prediction/t20s/README.txt:
# 100%|██████████| 1443/1443 [08:25<00:00,  2.86it/s]

# %% [markdown]
# # Create a copy of 'final_df' to preserve the original DataFrame in 'backup' for potential restoration or further analysis

# %%
backup = final_df.copy()

# %% [markdown]
# # Display the consolidated DataFrame containing normalized data from all JSON files

# %%
final_df
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Norway', 'deliverie...                0.9
# 1     [{'1st innings': {'team': 'Jersey', 'deliverie...                0.9
# 2     [{'1st innings': {'team': 'Namibia', 'deliveri...                0.9
# 3     [{'1st innings': {'team': 'Guernsey', 'deliver...                0.9
# 4     [{'1st innings': {'team': 'Australia', 'delive...                0.9
# ...                                                 ...                ...
# 1437  [{'1st innings': {'team': 'Jersey', 'deliverie...                0.9
# 1438  [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# 1439  [{'1st innings': {'team': 'Jersey', 'deliverie...                0.9
# 1440  [{'1st innings': {'team': 'Uganda', 'deliverie...                0.9
# 1441  [{'1st innings': {'team': 'South Africa', 'del...                0.9
#
#      meta.created  meta.revision                   info.venue    info.dates  \
# 0      2019-06-22              1                College Field  [2019-06-20]
# 1      2019-06-20              1  King George V Sports Ground  [2019-06-16]
# 2      2019-09-15              1        Kyambogo Cricket Oval  [2019-05-21]
# 3      2019-06-16              2  King George V Sports Ground  [2019-06-15]
# 4      2020-02-22              1        The Wanderers Stadium  [2020-02-21]
# ...           ...            ...                          ...           ...
# 1437   2019-06-23              1                College Field  [2019-06-19]
# 1438   2019-08-27              1                Sydney Parade  [2019-05-28]
# 1439   2019-06-22              1                College Field  [2019-06-20]
# 1440   2019-08-28              1          Lugogo Cricket Oval  [2019-05-20]
# 1441   2020-02-17              1                 Buffalo Park  [2020-02-12]
#
#      info.gender                 info.teams info.outcome.winner  \
# 0           male          [Germany, Norway]             Germany
# 1           male           [Jersey, Norway]              Jersey
# 2           male          [Uganda, Namibia]             Namibia
# 3           male        [Guernsey, Germany]             Germany
# 4           male  [South Africa, Australia]           Australia
# ...          ...                        ...                 ...
# 1437        male            [Italy, Jersey]              Jersey
# 1438      female     [Ireland, West Indies]         West Indies
# 1439        male          [Germany, Jersey]             Germany
# 1440        male         [Uganda, Botswana]              Uganda
# 1441        male    [South Africa, England]        South Africa
#
#       info.outcome.by.wickets  ... match_id info.outcome.by.runs  \
# 0                         7.0  ...        0                  NaN
# 1                         NaN  ...        1                 80.0
# 2                         NaN  ...        2                 42.0
# 3                         5.0  ...        3                  NaN
# 4                         NaN  ...        4                107.0
# ...                       ...  ...      ...                  ...
# 1437                      NaN  ...     1437                 73.0
# 1438                      NaN  ...     1438                 45.0
# 1439                      3.0  ...     1439                  NaN
# 1440                      NaN  ...     1440                 52.0
# 1441                      NaN  ...     1441                  1.0
#
#      info.outcome.result info.outcome.eliminator  info.outcome.method  \
# 0                    NaN                     NaN                  NaN
# 1                    NaN                     NaN                  NaN
# 2                    NaN                     NaN                  NaN
# 3                    NaN                     NaN                  NaN
# 4                    NaN                     NaN                  NaN
# ...                  ...                     ...                  ...
# 1437                 NaN                     NaN                  NaN
# 1438                 NaN                     NaN                  NaN
# 1439                 NaN                     NaN                  NaN
# 1440                 NaN                     NaN                  NaN
# 1441                 NaN                     NaN                  NaN
#
#       info.bowl_out info.outcome.bowl_out info.neutral_venue  \
# 0               NaN                   NaN                NaN
# 1               NaN                   NaN                NaN
# 2               NaN                   NaN                NaN
# 3               NaN                   NaN                NaN
# 4               NaN                   NaN                NaN
# ...             ...                   ...                ...
# 1437            NaN                   NaN                NaN
# 1438            NaN                   NaN                NaN
# 1439            NaN                   NaN                NaN
# 1440            NaN                   NaN                NaN
# 1441            NaN                   NaN                NaN
#
#       info.supersubs.New Zealand  info.supersubs.South Africa
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ...                          ...                          ...
# 1437                         NaN                          NaN
# 1438                         NaN                          NaN
# 1439                         NaN                          NaN
# 1440                         NaN                          NaN
# 1441                         NaN                          NaN
#
# [1442 rows x 28 columns]

# %% [markdown]
# # Count the occurrences of each unique value in the 'info.gender' column to analyze the distribution of gender in the data

# %%
final_df['info.gender'].value_counts()
# Out:
# info.gender
# male      966
# female    476
# Name: count, dtype: int64

# %% [markdown]
# # Filter the DataFrame to include only rows where 'info.gender' is 'male', then drop the 'info.gender' column

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
final_df
# Out:
# <ipython-input-8-75c075e09be7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.gender'],inplace=True)
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Norway', 'deliverie...                0.9
# 1     [{'1st innings': {'team': 'Jersey', 'deliverie...                0.9
# 2     [{'1st innings': {'team': 'Namibia', 'deliveri...                0.9
# 3     [{'1st innings': {'team': 'Guernsey', 'deliver...                0.9
# 4     [{'1st innings': {'team': 'Australia', 'delive...                0.9
# ...                                                 ...                ...
# 1436  [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
# 1437  [{'1st innings': {'team': 'Jersey', 'deliverie...                0.9
# 1439  [{'1st innings': {'team': 'Jersey', 'deliverie...                0.9
# 1440  [{'1st innings': {'team': 'Uganda', 'deliverie...                0.9
# 1441  [{'1st innings': {'team': 'South Africa', 'del...                0.9
#
#      meta.created  meta.revision                   info.venue    info.dates  \
# 0      2019-06-22              1                College Field  [2019-06-20]
# 1      2019-06-20              1  King George V Sports Ground  [2019-06-16]
# 2      2019-09-15              1        Kyambogo Cricket Oval  [2019-05-21]
# 3      2019-06-16              2  King George V Sports Ground  [2019-06-15]
# 4      2020-02-22              1        The Wanderers Stadium  [2020-02-21]
# ...           ...            ...                          ...           ...
# 1436   2019-11-06              1                  Manuka Oval  [2019-11-05]
# 1437   2019-06-23              1                College Field  [2019-06-19]
# 1439   2019-06-22              1                College Field  [2019-06-20]
# 1440   2019-08-28              1          Lugogo Cricket Oval  [2019-05-20]
# 1441   2020-02-17              1                 Buffalo Park  [2020-02-12]
#
#                      info.teams info.outcome.winner  info.outcome.by.wickets  \
# 0             [Germany, Norway]             Germany                      7.0
# 1              [Jersey, Norway]              Jersey                      NaN
# 2             [Uganda, Namibia]             Namibia                      NaN
# 3           [Guernsey, Germany]             Germany                      5.0
# 4     [South Africa, Australia]           Australia                      NaN
# ...                         ...                 ...                      ...
# 1436      [Australia, Pakistan]           Australia                      7.0
# 1437            [Italy, Jersey]              Jersey                      NaN
# 1439          [Germany, Jersey]             Germany                      3.0
# 1440         [Uganda, Botswana]              Uganda                      NaN
# 1441    [South Africa, England]        South Africa                      NaN
#
#      info.toss.decision  ... match_id info.outcome.by.runs  \
# 0                 field  ...        0                  NaN
# 1                   bat  ...        1                 80.0
# 2                   bat  ...        2                 42.0
# 3                 field  ...        3                  NaN
# 4                 field  ...        4                107.0
# ...                 ...  ...      ...                  ...
# 1436                bat  ...     1436                  NaN
# 1437              field  ...     1437                 73.0
# 1439              field  ...     1439                  NaN
# 1440              field  ...     1440                 52.0
# 1441              field  ...     1441                  1.0
#
#      info.outcome.result  info.outcome.eliminator  info.outcome.method  \
# 0                    NaN                      NaN                  NaN
# 1                    NaN                      NaN                  NaN
# 2                    NaN                      NaN                  NaN
# 3                    NaN                      NaN                  NaN
# 4                    NaN                      NaN                  NaN
# ...                  ...                      ...                  ...
# 1436                 NaN                      NaN                  NaN
# 1437                 NaN                      NaN                  NaN
# 1439                 NaN                      NaN                  NaN
# 1440                 NaN                      NaN                  NaN
# 1441                 NaN                      NaN                  NaN
#
#      info.bowl_out info.outcome.bowl_out  info.neutral_venue  \
# 0              NaN                   NaN                 NaN
# 1              NaN                   NaN                 NaN
# 2              NaN                   NaN                 NaN
# 3              NaN                   NaN                 NaN
# 4              NaN                   NaN                 NaN
# ...            ...                   ...                 ...
# 1436           NaN                   NaN                 NaN
# 1437           NaN                   NaN                 NaN
# 1439           NaN                   NaN                 NaN
# 1440           NaN                   NaN                 NaN
# 1441           NaN                   NaN                 NaN
#
#       info.supersubs.New Zealand info.supersubs.South Africa
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# ...                          ...                         ...
# 1436                         NaN                         NaN
# 1437                         NaN                         NaN
# 1439                         NaN                         NaN
# 1440                         NaN                         NaN
# 1441                         NaN                         NaN
#
# [966 rows x 27 columns]

# %% [markdown]
# # Count the occurrences of each unique value in the 'info.match_type' column to analyze the distribution of match types in the filtered data
# #In-short total T20 game played by male

# %%
final_df['info.match_type'].value_counts()
# Out:
# info.match_type
# T20    966
# Name: count, dtype: int64

# %% [markdown]
# # Count the occurrences of each unique value in the 'info.overs' column to analyze the distribution of overs in the filtered data
# #In-short total overs bowled

# %%
final_df['info.overs'].value_counts()
# Out:
# info.overs
# 20    963
# 50      3
# Name: count, dtype: int64

# %% [markdown]
# # Filter the DataFrame to include only rows where 'info.overs' is 20, then drop the 'info.overs' and 'info.match_type' columns

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df
# Out:
# <ipython-input-11-2ded84e4f63f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Norway', 'deliverie...                0.9
# 1     [{'1st innings': {'team': 'Jersey', 'deliverie...                0.9
# 2     [{'1st innings': {'team': 'Namibia', 'deliveri...                0.9
# 3     [{'1st innings': {'team': 'Guernsey', 'deliver...                0.9
# 4     [{'1st innings': {'team': 'Australia', 'delive...                0.9
# ...                                                 ...                ...
# 1436  [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
# 1437  [{'1st innings': {'team': 'Jersey', 'deliverie...                0.9
# 1439  [{'1st innings': {'team': 'Jersey', 'deliverie...                0.9
# 1440  [{'1st innings': {'team': 'Uganda', 'deliverie...                0.9
# 1441  [{'1st innings': {'team': 'South Africa', 'del...                0.9
#
#      meta.created  meta.revision                   info.venue    info.dates  \
# 0      2019-06-22              1                College Field  [2019-06-20]
# 1      2019-06-20              1  King George V Sports Ground  [2019-06-16]
# 2      2019-09-15              1        Kyambogo Cricket Oval  [2019-05-21]
# 3      2019-06-16              2  King George V Sports Ground  [2019-06-15]
# 4      2020-02-22              1        The Wanderers Stadium  [2020-02-21]
# ...           ...            ...                          ...           ...
# 1436   2019-11-06              1                  Manuka Oval  [2019-11-05]
# 1437   2019-06-23              1                College Field  [2019-06-19]
# 1439   2019-06-22              1                College Field  [2019-06-20]
# 1440   2019-08-28              1          Lugogo Cricket Oval  [2019-05-20]
# 1441   2020-02-17              1                 Buffalo Park  [2020-02-12]
#
#                      info.teams info.outcome.winner  info.outcome.by.wickets  \
# 0             [Germany, Norway]             Germany                      7.0
# 1              [Jersey, Norway]              Jersey                      NaN
# 2             [Uganda, Namibia]             Namibia                      NaN
# 3           [Guernsey, Germany]             Germany                      5.0
# 4     [South Africa, Australia]           Australia                      NaN
# ...                         ...                 ...                      ...
# 1436      [Australia, Pakistan]           Australia                      7.0
# 1437            [Italy, Jersey]              Jersey                      NaN
# 1439          [Germany, Jersey]             Germany                      3.0
# 1440         [Uganda, Botswana]              Uganda                      NaN
# 1441    [South Africa, England]        South Africa                      NaN
#
#      info.toss.decision  ... match_id info.outcome.by.runs  \
# 0                 field  ...        0                  NaN
# 1                   bat  ...        1                 80.0
# 2                   bat  ...        2                 42.0
# 3                 field  ...        3                  NaN
# 4                 field  ...        4                107.0
# ...                 ...  ...      ...                  ...
# 1436                bat  ...     1436                  NaN
# 1437              field  ...     1437                 73.0
# 1439              field  ...     1439                  NaN
# 1440              field  ...     1440                 52.0
# 1441              field  ...     1441                  1.0
#
#       info.outcome.result info.outcome.eliminator info.outcome.method  \
# 0                     NaN                     NaN                 NaN
# 1                     NaN                     NaN                 NaN
# 2                     NaN                     NaN                 NaN
# 3                     NaN                     NaN                 NaN
# 4                     NaN                     NaN                 NaN
# ...                   ...                     ...                 ...
# 1436                  NaN                     NaN                 NaN
# 1437                  NaN                     NaN                 NaN
# 1439                  NaN                     NaN                 NaN
# 1440                  NaN                     NaN                 NaN
# 1441                  NaN                     NaN                 NaN
#
#       info.bowl_out  info.outcome.bowl_out info.neutral_venue  \
# 0               NaN                    NaN                NaN
# 1               NaN                    NaN                NaN
# 2               NaN                    NaN                NaN
# 3               NaN                    NaN                NaN
# 4               NaN                    NaN                NaN
# ...             ...                    ...                ...
# 1436            NaN                    NaN                NaN
# 1437            NaN                    NaN                NaN
# 1439            NaN                    NaN                NaN
# 1440            NaN                    NaN                NaN
# 1441            NaN                    NaN                NaN
#
#      info.supersubs.New Zealand info.supersubs.South Africa
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ...                         ...                         ...
# 1436                        NaN                         NaN
# 1437                        NaN                         NaN
# 1439                        NaN                         NaN
# 1440                        NaN                         NaN
# 1441                        NaN                         NaN
#
# [963 rows x 25 columns]

# %% [markdown]
# # Serialize and save the 'final_df' DataFrame to a file named 'final_df.pkl' using pickle

# %%
import pickle
pickle.dump(final_df,open('final_df.pkl','wb'))

# %% [markdown]
# # Load the DataFrame 'final_df' from 'final_df.pkl' using pickle and access the 'deliveries' data for the first innings of the first match

# %%
matches = pickle.load(open('final_df.pkl','rb'))
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'P Agnihotri',
#    'batsman': 'Raza Iqbal'}},
#  {0.2: {'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'P Agnihotri',
#    'batsman': 'Raza Iqbal'}},
#  {0.3: {'non_striker': 'Raza Iqbal',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Agnihotri'}},
#  {0.4: {'non_striker': 'Raza Iqbal',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Agnihotri'}},
#  {0.5: {'non_striker': 'Raza Iqbal',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Agnihotri'}},
#  {0.6: {'non_striker': 'Raza Iqbal',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Agnihotri'}},
#  {1.1: {'non_striker': 'P Agnihotri',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Raza Iqbal'}},
#  {1.2: {'non_striker': 'Raza Iqbal',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Agnihotri'}},
#  {1.3: {'non_striker': 'Raza Iqbal',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Agnihotri'}},
#  {1.4: {'non_striker': 'Raza Iqbal',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Agnihotri'}},
#  {1.5: {'non_striker': 'P Agnihotri',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Raza Iqbal'}},
#  {1.6: {'non_striker': 'P Agnihotri',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Raza Iqbal'}},
#  {2.1: {'non_striker': 'P Agnihotri',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Raza Iqbal'}},
#  {2.2: {'non_striker': 'P Agnihotri',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Raza Iqbal'}},
#  {2.3: {'non_striker': 'Raza Iqbal',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Agnihotri'}},
#  {2.4: {'non_striker': 'P Agnihotri',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Raza Iqbal'}},
#  {2.5: {'non_striker': 'P Agnihotri',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Raza Iqbal'}},
#  {2.6: {'non_striker': 'Raza Iqbal',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Agnihotri'}},
#  {3.1: {'non_striker': 'Raza Iqbal',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Agnihotri'}},
#  {3.2: {'non_striker': 'Raza Iqbal',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Agnihotri'}},
#  {3.3: {'non_striker': 'P Agnihotri',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'Raza Iqbal'}},
#  {3.4: {'non_striker': 'P Agnihotri',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'Raza Iqbal'}},
#  {3.5: {'non_striker': 'P Agnihotri',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Raza Iqbal',
#    'wicket': {'player_out': 'Raza Iqbal',
#     'fielders': ['Amir Mangal'],
#     'kind': 'caught'}}},
#  {3.6: {'non_striker': 'P Agnihotri',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'E Ul Haq'}},
#  {4.1: {'non_striker': 'E Ul Haq',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Agnihotri'}},
#  {4.2: {'non_striker': 'P Agnihotri',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'E Ul Haq',
#    'wicket': {'player_out': 'E Ul Haq', 'kind': 'lbw'}}},
#  {4.3: {'non_striker': 'P Agnihotri',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'S Waqas Ahmed'}},
#  {4.4: {'non_striker': 'P Agnihotri',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'S Waqas Ahmed'}},
#  {4.5: {'non_striker': 'P Agnihotri',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'S Waqas Ahmed'}},
#  {4.6: {'non_striker': 'P Agnihotri',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'S Waqas Ahmed'}},
#  {5.1: {'non_striker': 'S Waqas Ahmed',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Agnihotri'}},
#  {5.2: {'non_striker': 'P Agnihotri',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'S Waqas Ahmed'}},
#  {5.3: {'non_striker': 'S Waqas Ahmed',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Agnihotri'}},
#  {5.4: {'non_striker': 'S Waqas Ahmed',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 2, 'total': 2, 'batsman': 0},
#    'extras': {'legbyes': 2},
#    'batsman': 'P Agnihotri'}},
#  {5.5: {'non_striker': 'S Waqas Ahmed',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Agnihotri'}},
#  {5.6: {'non_striker': 'S Waqas Ahmed',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Agnihotri'}},
#  {6.1: {'non_striker': 'P Agnihotri',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'S Waqas Ahmed'}},
#  {6.2: {'non_striker': 'P Agnihotri',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'S Waqas Ahmed',
#    'wicket': {'player_out': 'S Waqas Ahmed', 'kind': 'bowled'}}},
#  {6.3: {'non_striker': 'P Agnihotri',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Ansar Iqbal'}},
#  {6.4: {'non_striker': 'P Agnihotri',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Ansar Iqbal'}},
#  {6.5: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Agnihotri'}},
#  {6.6: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'CAJ Meschede',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'P Agnihotri'}},
#  {7.1: {'non_striker': 'P Agnihotri',
#    'bowler': 'Asad Mohammad',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Ansar Iqbal'}},
#  {7.2: {'non_striker': 'P Agnihotri',
#    'bowler': 'Asad Mohammad',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Ansar Iqbal'}},
#  {7.3: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Asad Mohammad',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Agnihotri'}},
#  {7.4: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Asad Mohammad',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'P Agnihotri'}},
#  {7.5: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Asad Mohammad',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Agnihotri'}},
#  {7.6: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Asad Mohammad',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Agnihotri'}},
#  {8.1: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Agnihotri'}},
#  {8.2: {'non_striker': 'P Agnihotri',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'Ansar Iqbal'}},
#  {8.3: {'non_striker': 'P Agnihotri',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Ansar Iqbal'}},
#  {8.4: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'P Agnihotri'}},
#  {8.5: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Agnihotri'}},
#  {8.6: {'non_striker': 'P Agnihotri',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Ansar Iqbal'}},
#  {9.1: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Agnihotri',
#    'wicket': {'player_out': 'P Agnihotri', 'kind': 'lbw'}}},
#  {9.2: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'Hayatullah Niazi'}},
#  {9.3: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'Hayatullah Niazi'}},
#  {9.4: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'Hayatullah Niazi'}},
#  {9.5: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'batsman': 'Hayatullah Niazi'}},
#  {9.6: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Hayatullah Niazi'}},
#  {9.7: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Hayatullah Niazi'}},
#  {10.1: {'non_striker': 'Hayatullah Niazi',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Ansar Iqbal'}},
#  {10.2: {'non_striker': 'Hayatullah Niazi',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Ansar Iqbal'}},
#  {10.3: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Hayatullah Niazi'}},
#  {10.4: {'non_striker': 'Hayatullah Niazi',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'Ansar Iqbal'}},
#  {10.5: {'non_striker': 'Hayatullah Niazi',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Ansar Iqbal'}},
#  {10.6: {'non_striker': 'Ansar Iqbal',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Hayatullah Niazi'}},
#  {11.1: {'non_striker': 'Hayatullah Niazi',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'Ansar Iqbal'}},
#  {11.2: {'non_striker': 'Hayatullah Niazi',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Ansar Iqbal'}},
#  {11.3: {'non_striker': 'Hayatullah Niazi',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Ansar Iqbal',
#    'wicket': {'player_out': 'Ansar Iqbal',
#     'fielders': ['R Pillai'],
#     'kind': 'caught'}}},
#  {11.4: {'non_striker': 'Hayatullah Niazi',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Nazakat Ali'}},
#  {11.5: {'non_striker': 'Hayatullah Niazi',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Nazakat Ali'}},
#  {11.6: {'non_striker': 'Nazakat Ali',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Hayatullah Niazi'}},
#  {12.1: {'non_striker': 'Hayatullah Niazi',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Nazakat Ali'}},
#  {12.2: {'non_striker': 'Nazakat Ali',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Hayatullah Niazi'}},
#  {12.3: {'non_striker': 'Hayatullah Niazi',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Nazakat Ali'}},
#  {12.4: {'non_striker': 'Hayatullah Niazi',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Nazakat Ali'}},
#  {12.5: {'non_striker': 'Nazakat Ali',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Hayatullah Niazi',
#    'wicket': {'player_out': 'Hayatullah Niazi',
#     'fielders': ['Asad Mohammad'],
#     'kind': 'caught'}}},
#  {12.6: {'non_striker': 'Nazakat Ali',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'noballs': 1},
#    'batsman': 'Khizer Ahmed'}},
#  {12.7: {'non_striker': 'Nazakat Ali',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Khizer Ahmed'}},
#  {13.1: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Nazakat Ali'}},
#  {13.2: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Nazakat Ali'}},
#  {13.3: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Nazakat Ali'}},
#  {13.4: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Nazakat Ali'}},
#  {13.5: {'non_striker': 'Nazakat Ali',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'Khizer Ahmed'}},
#  {13.6: {'non_striker': 'Nazakat Ali',
#    'bowler': 'Muslim Yar',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Khizer Ahmed'}},
#  {14.1: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Nazakat Ali'}},
#  {14.2: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Nazakat Ali'}},
#  {14.3: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Nazakat Ali'}},
#  {14.4: {'non_striker': 'Nazakat Ali',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Khizer Ahmed'}},
#  {14.5: {'non_striker': 'Nazakat Ali',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Khizer Ahmed'}},
#  {14.6: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Sahir Naqash',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Nazakat Ali'}},
#  {15.1: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'Nazakat Ali'}},
#  {15.2: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Nazakat Ali',
#    'wicket': {'player_out': 'Nazakat Ali', 'kind': 'bowled'}}},
#  {15.3: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Tafseer Ali'}},
#  {15.4: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Tafseer Ali'}},
#  {15.5: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Tafseer Ali'}},
#  {15.6: {'non_striker': 'Tafseer Ali',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Khizer Ahmed'}},
#  {16.1: {'non_striker': 'Tafseer Ali',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Khizer Ahmed'}},
#  {16.2: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Tafseer Ali'}},
#  {16.3: {'non_striker': 'Tafseer Ali',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Khizer Ahmed',
#    'wicket': {'player_out': 'Tafseer Ali', 'kind': 'run out'}}},
#  {16.4: {'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'Junaid Sheikh',
#    'batsman': 'Khizer Ahmed'}},
#  {16.5: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Junaid Sheikh'}},
#  {16.6: {'non_striker': 'Junaid Sheikh',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Khizer Ahmed'}},
#  {17.1: {'non_striker': 'Junaid Sheikh',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Khizer Ahmed'}},
#  {17.2: {'non_striker': 'Junaid Sheikh',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'Khizer Ahmed'}},
#  {17.3: {'non_striker': 'Junaid Sheikh',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Khizer Ahmed'}},
#  {17.4: {'non_striker': 'Junaid Sheikh',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Khizer Ahmed'}},
#  {17.5: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Junaid Sheikh',
#    'wicket': {'player_out': 'Junaid Sheikh', 'kind': 'bowled'}}},
#  {17.6: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Izatullah Dawlatzai',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Bhart'}},
#  {18.1: {'non_striker': 'P Bhart',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Khizer Ahmed'}},
#  {18.2: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Bhart'}},
#  {18.3: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Bhart'}},
#  {18.4: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Bhart'}},
#  {18.5: {'non_striker': 'P Bhart',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Khizer Ahmed'}},
#  {18.6: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Ahmed Wardak',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Bhart'}},
#  {19.1: {'non_striker': 'P Bhart',
#    'bowler': 'Asad Mohammad',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Khizer Ahmed'}},
#  {19.2: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Asad Mohammad',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Bhart'}},
#  {19.3: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Asad Mohammad',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'P Bhart'}},
#  {19.4: {'non_striker': 'Khizer Ahmed',
#    'bowler': 'Asad Mohammad',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'P Bhart'}},
#  {19.5: {'non_striker': 'P Bhart',
#    'bowler': 'Asad Mohammad',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'Khizer Ahmed'}},
#  {19.6: {'non_striker': 'P Bhart',
#    'bowler': 'Asad Mohammad',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Khizer Ahmed',
#    'wicket': {'player_out': 'Khizer Ahmed', 'kind': 'run out'}}}]

# %% [markdown]
# # Process each row in 'matches' to extract delivery data, skipping specific match indices, and compile it into 'delivery_df'; handles missing 'wicket' keys by appending '0' for undismissed players

# %%
count=1
delivery_df = pd.DataFrame()
for index , row in matches.iterrows():
  if count in [75,108,150,180,268,360,443,458,583,982,1052,1111,1226,1345]:
    count+=1
    continue
  count+=1
  ball_of_match = []
  batsman = []
  bowler = []
  runs = []
  player_of_dismis=[]
  teams = []
  batting_team = []
  match_id = []
  city = []
  venue = []
  for ball in row['innings'][0]['1st innings']['deliveries']:
    for key in ball.keys():
      match_id.append(count)
      batting_team.append(row['innings'][0]['1st innings']['team'])
      teams.append(row['info.teams'])
      ball_of_match.append(key)
      batsman.append(ball[key]['batsman'])
      bowler.append(ball[key]['bowler'])
      runs.append(ball[key]['runs']['total'])
      city.append(row['info.city'])
      venue.append(row['info.venue'])
      try:
        player_of_dismis.append(ball[key]['wicket']['player_out'])
      except:
        player_of_dismis.append('0')
  loop_df = pd.DataFrame({
    'match_id':match_id,
    'teams':teams,
    'batting_team':batting_team,
    'ball':ball_of_match,
    'batsman':batsman,
    'bowler':bowler,
    'runs':runs,
    'player_dismissed':player_of_dismis,
    'city':city,
    'venue':venue
  })

  delivery_df = pd.concat([delivery_df,loop_df],ignore_index=True)

# %% [markdown]
# # Display the DataFrame 'delivery_df' containing aggregated delivery-level data from multiple matches

# %%
delivery_df
# Out:
#         match_id                    teams  batting_team  ball         batsman  \
# 0              2        [Germany, Norway]        Norway   0.1      Raza Iqbal
# 1              2        [Germany, Norway]        Norway   0.2      Raza Iqbal
# 2              2        [Germany, Norway]        Norway   0.3     P Agnihotri
# 3              2        [Germany, Norway]        Norway   0.4     P Agnihotri
# 4              2        [Germany, Norway]        Norway   0.5     P Agnihotri
# ...          ...                      ...           ...   ...             ...
# 115425       964  [South Africa, England]  South Africa  19.2    BE Hendricks
# 115426       964  [South Africa, England]  South Africa  19.3        DW Steyn
# 115427       964  [South Africa, England]  South Africa  19.4        DW Steyn
# 115428       964  [South Africa, England]  South Africa  19.5  AL Phehlukwayo
# 115429       964  [South Africa, England]  South Africa  19.6  AL Phehlukwayo
#
#               bowler  runs player_dismissed           city          venue
# 0       CAJ Meschede     0                0  St Peter Port  College Field
# 1       CAJ Meschede     1                0  St Peter Port  College Field
# 2       CAJ Meschede     0                0  St Peter Port  College Field
# 3       CAJ Meschede     0                0  St Peter Port  College Field
# 4       CAJ Meschede     0                0  St Peter Port  College Field
# ...              ...   ...              ...            ...            ...
# 115425     CJ Jordan     0     BE Hendricks    East London   Buffalo Park
# 115426     CJ Jordan     4                0    East London   Buffalo Park
# 115427     CJ Jordan     1                0    East London   Buffalo Park
# 115428     CJ Jordan     0                0    East London   Buffalo Park
# 115429     CJ Jordan     0   AL Phehlukwayo    East London   Buffalo Park
#
# [115430 rows x 10 columns]

# %% [markdown]
# # Function to determine the bowling team by returning the team from 'teams' list that is not the 'batting_team'

# %%
def bowl(row):
  for team in row['teams']:
    if team != row['batting_team']:
      return team

# %% [markdown]
# # Apply the 'bowl' function to each row of 'delivery_df' to determine the bowling team and store the result in a new column 'bowling_team'

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %% [markdown]
# # Drop the 'teams' column from 'delivery_df' as it is no longer needed after determining the bowling team

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %% [markdown]
# # Get an array of unique values in the 'batting_team' column to see which teams are listed as batting teams

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Norway', 'Jersey', 'Namibia', 'Guernsey', 'Australia',
#        'South Africa', 'Ghana', 'Kenya', 'Italy', 'Denmark', 'Nigeria',
#        'New Zealand', 'Thailand', 'England', 'India', 'Malaysia',
#        'Netherlands', 'West Indies', 'Bangladesh', 'Maldives', 'Nepal',
#        'Kuwait', 'Afghanistan', 'Singapore', 'Sri Lanka', 'Bermuda',
#        'Zimbabwe', 'Cayman Islands', 'Canada', 'United States of America',
#        'Botswana', 'Ireland', 'Hong Kong', 'Scotland',
#        'United Arab Emirates', 'Papua New Guinea', 'Oman', 'Pakistan',
#        'Gibraltar', 'Vanuatu', 'Spain', 'Portugal', 'Bhutan', 'Germany',
#        'Qatar', 'Iran', 'Belgium', 'Isle of Man', 'Romania', 'Bulgaria',
#        'Philippines', 'Uganda'], dtype=object)

# %% [markdown]
# # List of cricket teams included in the dataset

# %%
teams =[
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'
]

# %% [markdown]
# # Filter 'delivery_df' to include only rows where both 'batting_team' and 'bowling_team' are in the predefined list of teams

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]
#

# %% [markdown]
# # Display the filtered DataFrame 'delivery_df' containing deliveries where both batting and bowling teams are in the predefined list of teams

# %%
delivery_df
# Out:
#         match_id  batting_team  ball         batsman     bowler  runs  \
# 491            6     Australia   0.1       DA Warner   DW Steyn     4
# 492            6     Australia   0.2       DA Warner   DW Steyn     0
# 493            6     Australia   0.3        AJ Finch   DW Steyn     4
# 494            6     Australia   0.4        AJ Finch   DW Steyn     1
# 495            6     Australia   0.5       SPD Smith   DW Steyn     0
# ...          ...           ...   ...             ...        ...   ...
# 115425       964  South Africa  19.2    BE Hendricks  CJ Jordan     0
# 115426       964  South Africa  19.3        DW Steyn  CJ Jordan     4
# 115427       964  South Africa  19.4        DW Steyn  CJ Jordan     1
# 115428       964  South Africa  19.5  AL Phehlukwayo  CJ Jordan     0
# 115429       964  South Africa  19.6  AL Phehlukwayo  CJ Jordan     0
#
#        player_dismissed          city                  venue  bowling_team
# 491                   0  Johannesburg  The Wanderers Stadium  South Africa
# 492           DA Warner  Johannesburg  The Wanderers Stadium  South Africa
# 493                   0  Johannesburg  The Wanderers Stadium  South Africa
# 494                   0  Johannesburg  The Wanderers Stadium  South Africa
# 495                   0  Johannesburg  The Wanderers Stadium  South Africa
# ...                 ...           ...                    ...           ...
# 115425     BE Hendricks   East London           Buffalo Park       England
# 115426                0   East London           Buffalo Park       England
# 115427                0   East London           Buffalo Park       England
# 115428                0   East London           Buffalo Park       England
# 115429   AL Phehlukwayo   East London           Buffalo Park       England
#
# [63985 rows x 10 columns]

# %% [markdown]
# # Create a new DataFrame 'op' with selected columns from 'delivery_df' to include relevant details for further analysis

# %%
op = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %% [markdown]
# # Display the 'op' DataFrame containing relevant columns for each delivery, including match details and performance metrics

# %%
op
# Out:
#         match_id  batting_team  bowling_team  ball  runs player_dismissed  \
# 491            6     Australia  South Africa   0.1     4                0
# 492            6     Australia  South Africa   0.2     0        DA Warner
# 493            6     Australia  South Africa   0.3     4                0
# 494            6     Australia  South Africa   0.4     1                0
# 495            6     Australia  South Africa   0.5     0                0
# ...          ...           ...           ...   ...   ...              ...
# 115425       964  South Africa       England  19.2     0     BE Hendricks
# 115426       964  South Africa       England  19.3     4                0
# 115427       964  South Africa       England  19.4     1                0
# 115428       964  South Africa       England  19.5     0                0
# 115429       964  South Africa       England  19.6     0   AL Phehlukwayo
#
#                 city                  venue
# 491     Johannesburg  The Wanderers Stadium
# 492     Johannesburg  The Wanderers Stadium
# 493     Johannesburg  The Wanderers Stadium
# 494     Johannesburg  The Wanderers Stadium
# 495     Johannesburg  The Wanderers Stadium
# ...              ...                    ...
# 115425   East London           Buffalo Park
# 115426   East London           Buffalo Park
# 115427   East London           Buffalo Park
# 115428   East London           Buffalo Park
# 115429   East London           Buffalo Park
#
# [63985 rows x 8 columns]

# %% [markdown]
# # Serialize and save the 'op' DataFrame to a file named 'delivery_df.pkl' using pickle for later use

# %%
pickle.dump(op,open('delivery_df.pkl','wb'))

# %% [markdown]
# # Display the 'op' DataFrame containing selected columns with delivery details and match information

# %%
op
# Out:
#         match_id  batting_team  bowling_team  ball  runs player_dismissed  \
# 491            6     Australia  South Africa   0.1     4                0
# 492            6     Australia  South Africa   0.2     0        DA Warner
# 493            6     Australia  South Africa   0.3     4                0
# 494            6     Australia  South Africa   0.4     1                0
# 495            6     Australia  South Africa   0.5     0                0
# ...          ...           ...           ...   ...   ...              ...
# 115425       964  South Africa       England  19.2     0     BE Hendricks
# 115426       964  South Africa       England  19.3     4                0
# 115427       964  South Africa       England  19.4     1                0
# 115428       964  South Africa       England  19.5     0                0
# 115429       964  South Africa       England  19.6     0   AL Phehlukwayo
#
#                 city                  venue
# 491     Johannesburg  The Wanderers Stadium
# 492     Johannesburg  The Wanderers Stadium
# 493     Johannesburg  The Wanderers Stadium
# 494     Johannesburg  The Wanderers Stadium
# 495     Johannesburg  The Wanderers Stadium
# ...              ...                    ...
# 115425   East London           Buffalo Park
# 115426   East London           Buffalo Park
# 115427   East London           Buffalo Park
# 115428   East London           Buffalo Park
# 115429   East London           Buffalo Park
#
# [63985 rows x 8 columns]

# %% [markdown]
# # Save the 'op' DataFrame to a CSV file named 'delivery_df.csv', excluding the index column

# %%
op.to_csv('delivery_df.csv', index=False)

# %% [markdown]
# # Display the 'op' DataFrame containing delivery-level data with match details, batting and bowling teams, and performance metrics

# %%
op
# Out:
#         match_id  batting_team  bowling_team  ball  runs player_dismissed  \
# 491            6     Australia  South Africa   0.1     4                0
# 492            6     Australia  South Africa   0.2     0        DA Warner
# 493            6     Australia  South Africa   0.3     4                0
# 494            6     Australia  South Africa   0.4     1                0
# 495            6     Australia  South Africa   0.5     0                0
# ...          ...           ...           ...   ...   ...              ...
# 115425       964  South Africa       England  19.2     0     BE Hendricks
# 115426       964  South Africa       England  19.3     4                0
# 115427       964  South Africa       England  19.4     1                0
# 115428       964  South Africa       England  19.5     0                0
# 115429       964  South Africa       England  19.6     0   AL Phehlukwayo
#
#                 city                  venue
# 491     Johannesburg  The Wanderers Stadium
# 492     Johannesburg  The Wanderers Stadium
# 493     Johannesburg  The Wanderers Stadium
# 494     Johannesburg  The Wanderers Stadium
# 495     Johannesburg  The Wanderers Stadium
# ...              ...                    ...
# 115425   East London           Buffalo Park
# 115426   East London           Buffalo Park
# 115427   East London           Buffalo Park
# 115428   East London           Buffalo Park
# 115429   East London           Buffalo Park
#
# [63985 rows x 8 columns]
